# %% [markdown]
# # Setup

# %%
# %load_ext autoreload

# %%
# %autoreload

import my_functions as mf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from pycaret.regression import *
# from pycaret.time_series import *

# %%
# Loading Y training data for A:
Y_train_a = pd.read_parquet('data/A/train_targets.parquet')
Y_train_a["pv_measurement"] = np.sqrt(Y_train_a["pv_measurement"])

# Loading X training data for A:
X_train_a = pd.concat([pd.read_parquet('data/A/X_train_observed.parquet'), pd.read_parquet('data/A/X_train_estimated.parquet').drop("date_calc", axis=1)])

# Loading X test data for A:
X_test_a = pd.read_parquet('data/A/X_test_estimated.parquet').drop("date_calc", axis=1)

Y_train_a_clean, X_train_a_clean, X_test_a_clean, X_a_clean, train_a_clean = mf.full_clean(Y_train_a,X_train_a,X_test_a)
# Y_train_a_clean_hourly, X_train_a_clean_hourly, X_test_a_clean_hourly, X_a_clean_hourly = full_clean(Y_train_a,X_train_a,X_test_a,False)

# Loading Y training data for B:
Y_train_b = pd.read_parquet('data/B/train_targets.parquet')
Y_train_b["pv_measurement"] = np.sqrt(Y_train_b["pv_measurement"])

# Loading X training data for B:
X_train_b = pd.concat([pd.read_parquet('data/B/X_train_observed.parquet'), pd.read_parquet('data/B/X_train_estimated.parquet').drop("date_calc", axis=1)])

# Loading X test data for B:
X_test_b = pd.read_parquet('data/B/X_test_estimated.parquet').drop("date_calc", axis=1)

Y_train_b_clean, X_train_b_clean, X_test_b_clean, X_b_clean, train_b_clean = mf.full_clean(Y_train_b,X_train_b,X_test_b)
# Y_train_b_clean_hourly, X_train_b_clean_hourly, X_test_b_clean_hourly, X_b_clean_hourly = full_clean(Y_train_b,X_train_b,X_test_b,False)

# Loading Y training data for C:
Y_train_c = pd.read_parquet('data/C/train_targets.parquet')
Y_train_c["pv_measurement"] = np.sqrt(Y_train_c["pv_measurement"])

# Loading X training data for C:
X_train_c = pd.concat([pd.read_parquet('data/C/X_train_observed.parquet'), pd.read_parquet('data/C/X_train_estimated.parquet').drop("date_calc", axis=1)])

# Loading X test data for C:
X_test_c = pd.read_parquet('data/C/X_test_estimated.parquet').drop("date_calc", axis=1)

Y_train_c_clean, X_train_c_clean, X_test_c_clean, X_c_clean, train_c_clean = mf.full_clean(Y_train_c,X_train_c,X_test_c)
# Y_train_c_clean_hourly, X_train_c_clean_hourly, X_test_c_clean_hourly, X_c_clean_hourly = full_clean(Y_train_c,X_train_c,X_test_c,False)

# %% [markdown]
# # Main stuff:

# %% [markdown]
# ## A:

# %%
setup_a = setup(train_a_clean, target = "pv_measurement", train_size = 0.975, categorical_features = ["dew_or_rime__idx", "elevation__m", "is_day__idx", "is_in_shadow__idx", "precip_type_5min__idx", "snow_drift__idx", "wind_speed_w_1000hPa__ms"], session_id = 0)
# Out:
# <style type="text/css">
# #T_e571e_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e571e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e571e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e571e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e571e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e571e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e571e_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e571e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e571e_row1_col1" class="data row1 col1" >pv_measurement</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e571e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e571e_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e571e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e571e_row3_col1" class="data row3 col1" >(34061, 43)</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e571e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e571e_row4_col1" class="data row4 col1" >(34061, 75)</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e571e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e571e_row5_col1" class="data row5 col1" >(33209, 75)</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e571e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e571e_row6_col1" class="data row6 col1" >(852, 75)</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e571e_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_e571e_row7_col1" class="data row7 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e571e_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_e571e_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e571e_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_e571e_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e571e_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_e571e_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e571e_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_e571e_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e571e_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_e571e_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e571e_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_e571e_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e571e_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_e571e_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e571e_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_e571e_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e571e_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_e571e_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e571e_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_e571e_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e571e_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_e571e_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e571e_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_e571e_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e571e_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_e571e_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e571e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e571e_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_e571e_row21_col1" class="data row21 col1" >2e18</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_a = setup_a.compare_models(sort = "MAE", fold = 10)

# %%
tuned_best_a = tune_model(best_a, optimize = "MAE", fold = 5, n_iter = 10)

# %%
# evaluate_model(best_a)
# tuned_best_a = tune_model(best_a, optimize = "MAE", fold = 10, n_iter = 100)
# pred_holdout = predict_model(best_a)
# predictions = predict_model(besta, data=X_test_a_clean)
# predictions.iloc[:,-1:]

# %%
# setup_a.create_model("et")

# %%
# best_a = compare_models(fold = 20, sort = "MAE", exclude = ["lar"])

# %%
# evaluate_model(besta)
# pred_holdout = predict_model(besta)
# predictions = predict_model(besta, data=X_test_a_clean)
# predictions.iloc[:,-1:]

# %%
et_a = create_model("et")
# tuned_et_a = tune_model(et_a)
final_et_a = finalize_model(et_a)
pred_et_a_holdout = predict_model(final_et_a)
predictions_et_a = predict_model(final_et_a, data = X_test_a_clean).iloc[:,-1:]
predictions_et_a[predictions_et_a < 0 ] = 0

# %%
lightgbm_a = create_model("lightgbm")
tuned_lightgbm_a = tune_model(lightgbm_a)
final_lightgbm_a = finalize_model(tuned_lightgbm_a)
pred_lightgbm_a_holdout = predict_model(final_lightgbm_a)
predictions_lightgbm_a = predict_model(final_lightgbm_a, data = X_test_a_clean).iloc[:,-1:]
predictions_lightgbm_a[predictions_lightgbm_a < 0 ] = 0

# %%
cat_a = setup_a.create_model("catboost")
tuned_cat_a = tune_model(cat_a)
final_cat_a = finalize_model(tuned_cat_a)
pred_cat_a_holdout = predict_model(final_cat_a)
predictions_cat_a = predict_model(final_cat_a, data = X_test_a_clean).iloc[:,-1:]
predictions_cat_a[predictions_cat_a < 0 ] = 0
# Out:
# <style type="text/css">
# #T_07579_row10_col0, #T_07579_row10_col1, #T_07579_row10_col2, #T_07579_row10_col3, #T_07579_row10_col4, #T_07579_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_07579">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07579_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_07579_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_07579_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_07579_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_07579_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_07579_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07579_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07579_row0_col0" class="data row0 col0" >2.6363</td>
#       <td id="T_07579_row0_col1" class="data row0 col1" >23.8239</td>
#       <td id="T_07579_row0_col2" class="data row0 col2" >4.8810</td>
#       <td id="T_07579_row0_col3" class="data row0 col3" >0.9439</td>
#       <td id="T_07579_row0_col4" class="data row0 col4" >0.3135</td>
#       <td id="T_07579_row0_col5" class="data row0 col5" >0.3020</td>
#     </tr>
#     <tr>
#       <th id="T_07579_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07579_row1_col0" class="data row1 col0" >2.7171</td>
#       <td id="T_07579_row1_col1" class="data row1 col1" >25.0329</td>
#       <td id="T_07579_row1_col2" class="data row1 col2" >5.0033</td>
#       <td id="T_07579_row1_col3" class="data row1 col3" >0.9396</td>
#       <td id="T_07579_row1_col4" class="data row1 col4" >0.3074</td>
#       <td id="T_07579_row1_col5" class="data row1 col5" >0.2957</td>
#     </tr>
#     <tr>
#       <th id="T_07579_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_07579_row2_col0" class="data row2 col0" >2.7933</td>
#       <td id="T_07579_row2_col1" class="data row2 col1" >26.0110</td>
#       <td id="T_07579_row2_col2" class="data row2 col2" >5.1001</td>
#       <td id="T_07579_row2_col3" class="data row2 col3" >0.9321</td>
#       <td id="T_07579_row2_col4" class="data row2 col4" >0.3147</td>
#       <td id="T_07579_row2_col5" class="data row2 col5" >0.3126</td>
#     </tr>
#     <tr>
#       <th id="T_07579_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_07579_row3_col0" class="data row3 col0" >2.6761</td>
#       <td id="T_07579_row3_col1" class="data row3 col1" >24.9828</td>
#       <td id="T_07579_row3_col2" class="data row3 col2" >4.9983</td>
#       <td id="T_07579_row3_col3" class="data row3 col3" >0.9405</td>
#       <td id="T_07579_row3_col4" class="data row3 col4" >0.3145</td>
#       <td id="T_07579_row3_col5" class="data row3 col5" >0.2769</td>
#     </tr>
#     <tr>
#       <th id="T_07579_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_07579_row4_col0" class="data row4 col0" >2.6897</td>
#       <td id="T_07579_row4_col1" class="data row4 col1" >25.1481</td>
#       <td id="T_07579_row4_col2" class="data row4 col2" >5.0148</td>
#       <td id="T_07579_row4_col3" class="data row4 col3" >0.9383</td>
#       <td id="T_07579_row4_col4" class="data row4 col4" >0.3005</td>
#       <td id="T_07579_row4_col5" class="data row4 col5" >0.2869</td>
#     </tr>
#     <tr>
#       <th id="T_07579_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_07579_row5_col0" class="data row5 col0" >2.7069</td>
#       <td id="T_07579_row5_col1" class="data row5 col1" >24.8012</td>
#       <td id="T_07579_row5_col2" class="data row5 col2" >4.9801</td>
#       <td id="T_07579_row5_col3" class="data row5 col3" >0.9398</td>
#       <td id="T_07579_row5_col4" class="data row5 col4" >0.3137</td>
#       <td id="T_07579_row5_col5" class="data row5 col5" >0.2769</td>
#     </tr>
#     <tr>
#       <th id="T_07579_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_07579_row6_col0" class="data row6 col0" >2.6565</td>
#       <td id="T_07579_row6_col1" class="data row6 col1" >24.5567</td>
#       <td id="T_07579_row6_col2" class="data row6 col2" >4.9555</td>
#       <td id="T_07579_row6_col3" class="data row6 col3" >0.9394</td>
#       <td id="T_07579_row6_col4" class="data row6 col4" >0.3093</td>
#       <td id="T_07579_row6_col5" class="data row6 col5" >0.2966</td>
#     </tr>
#     <tr>
#       <th id="T_07579_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_07579_row7_col0" class="data row7 col0" >2.6037</td>
#       <td id="T_07579_row7_col1" class="data row7 col1" >23.8565</td>
#       <td id="T_07579_row7_col2" class="data row7 col2" >4.8843</td>
#       <td id="T_07579_row7_col3" class="data row7 col3" >0.9416</td>
#       <td id="T_07579_row7_col4" class="data row7 col4" >0.2980</td>
#       <td id="T_07579_row7_col5" class="data row7 col5" >0.2719</td>
#     </tr>
#     <tr>
#       <th id="T_07579_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_07579_row8_col0" class="data row8 col0" >2.6798</td>
#       <td id="T_07579_row8_col1" class="data row8 col1" >24.9771</td>
#       <td id="T_07579_row8_col2" class="data row8 col2" >4.9977</td>
#       <td id="T_07579_row8_col3" class="data row8 col3" >0.9371</td>
#       <td id="T_07579_row8_col4" class="data row8 col4" >0.3078</td>
#       <td id="T_07579_row8_col5" class="data row8 col5" >0.3051</td>
#     </tr>
#     <tr>
#       <th id="T_07579_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_07579_row9_col0" class="data row9 col0" >2.5892</td>
#       <td id="T_07579_row9_col1" class="data row9 col1" >25.1998</td>
#       <td id="T_07579_row9_col2" class="data row9 col2" >5.0199</td>
#       <td id="T_07579_row9_col3" class="data row9 col3" >0.9374</td>
#       <td id="T_07579_row9_col4" class="data row9 col4" >0.3281</td>
#       <td id="T_07579_row9_col5" class="data row9 col5" >0.2812</td>
#     </tr>
#     <tr>
#       <th id="T_07579_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_
td>
#     </tr>
#     <tr>
#       <th id="T_0ab1c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0ab1c_row4_col0" class="data row4 col0" >2.7282</td>
#       <td id="T_0ab1c_row4_col1" class="data row4 col1" >25.7179</td>
#       <td id="T_0ab1c_row4_col2" class="data row4 col2" >5.0713</td>
#       <td id="T_0ab1c_row4_col3" class="data row4 col3" >0.9369</td>
#       <td id="T_0ab1c_row4_col4" class="data row4 col4" >0.3111</td>
#       <td id="T_0ab1c_row4_col5" class="data row4 col5" >0.2890</td>
#     </tr>
#     <tr>
#       <th id="T_0ab1c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0ab1c_row5_col0" class="data row5 col0" >2.7795</td>
#       <td id="T_0ab1c_row5_col1" class="data row5 col1" >25.8057</td>
#       <td id="T_0ab1c_row5_col2" class="data row5 col2" >5.0799</td>
#       <td id="T_0ab1c_row5_col3" class="data row5 col3" >0.9374</td>
#       <td id="T_0ab1c_row5_col4" class="data row5 col4" >0.3281</td>
#       <td id="T_0ab1c_row5_col5" class="data row5 col5" >0.2758</td>
#     </tr>
#     <tr>
#       <th id="T_0ab1c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0ab1c_row6_col0" class="data row6 col0" >2.7404</td>
#       <td id="T_0ab1c_row6_col1" class="data row6 col1" >25.5901</td>
#       <td id="T_0ab1c_row6_col2" class="data row6 col2" >5.0587</td>
#       <td id="T_0ab1c_row6_col3" class="data row6 col3" >0.9368</td>
#       <td id="T_0ab1c_row6_col4" class="data row6 col4" >0.3352</td>
#       <td id="T_0ab1c_row6_col5" class="data row6 col5" >0.3018</td>
#     </tr>
#     <tr>
#       <th id="T_0ab1c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0ab1c_row7_col0" class="data row7 col0" >2.7100</td>
#       <td id="T_0ab1c_row7_col1" class="data row7 col1" >25.1258</td>
#       <td id="T_0ab1c_row7_col2" class="data row7 col2" >5.0126</td>
#       <td id="T_0ab1c_row7_col3" class="data row7 col3" >0.9385</td>
#       <td id="T_0ab1c_row7_col4" class="data row7 col4" >0.3233</td>
#       <td id="T_0ab1c_row7_col5" class="data row7 col5" >0.2808</td>
#     </tr>
#     <tr>
#       <th id="T_0ab1c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0ab1c_row8_col0" class="data row8 col0" >2.7461</td>
#       <td id="T_0ab1c_row8_col1" class="data row8 col1" >26.0269</td>
#       <td id="T_0ab1c_row8_col2" class="data row8 col2" >5.1017</td>
#       <td id="T_0ab1c_row8_col3" class="data row8 col3" >0.9345</td>
#       <td id="T_0ab1c_row8_col4" class="data row8 col4" >0.3213</td>
#       <td id="T_0ab1c_row8_col5" class="data row8 col5" >0.3141</td>
#     </tr>
#     <tr>
#       <th id="T_0ab1c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0ab1c_row9_col0" class="data row9 col0" >2.6413</td>
#       <td id="T_0ab1c_row9_col1" class="data row9 col1" >25.8507</td>
#       <td id="T_0ab1c_row9_col2" class="data row9 col2" >5.0844</td>
#       <td id="T_0ab1c_row9_col3" class="data row9 col3" >0.9358</td>
#       <td id="T_0ab1c_row9_col4" class="data row9 col4" >0.3477</td>
#       <td id="T_0ab1c_row9_col5" class="data row9 col5" >0.2844</td>
#     </tr>
#     <tr>
#       <th id="T_0ab1c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_0ab1c_row10_col0" class="data row10 col0" >2.7538</td>
#       <td id="T_0ab1c_row10_col1" class="data row10 col1" >25.8407</td>
#       <td id="T_0ab1c_row10_col2" class="data row10 col2" >5.0831</td>
#       <td id="T_0ab1c_row10_col3" class="data row10 col3" >0.9365</td>
#       <td id="T_0ab1c_row10_col4" class="data row10 col4" >0.3317</td>
#       <td id="T_0ab1c_row10_col5" class="data row10 col5" >0.2973</td>
#     </tr>
#     <tr>
#       <th id="T_0ab1c_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_0ab1c_row11_col0" class="data row11 col0" >0.0560</td>
#       <td id="T_0ab1c_row11_col1" class="data row11 col1" >0.5220</td>
#       <td id="T_0ab1c_row11_col2" class="data row11 col2" >0.0514</td>
#       <td id="T_0ab1c_row11_col3" class="data row11 col3" >0.0026</td>
#       <td id="T_0ab1c_row11_col4" class="data row11 col4" >0.0110</td>
#       <td id="T_0ab1c_row11_col5" class="data row11 col5" >0.0158</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# </style>
# <table id="T_732b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_732b8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_732b8_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_732b8_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_732b8_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_732b8_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_732b8_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_732b8_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_732b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_732b8_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_732b8_row0_col1" class="data row0 col1" >2.2263</td>
#       <td id="T_732b8_row0_col2" class="data row0 col2" >16.8071</td>
#       <td id="T_732b8_row0_col3" class="data row0 col3" >4.0996</td>
#       <td id="T_732b8_row0_col4" class="data row0 col4" >0.9601</td>
#       <td id="T_732b8_row0_col5" class="data row0 col5" >0.2913</td>
#       <td id="T_732b8_row0_col6" class="data row0 col6" >0.2546</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## B:

# %%
setup_b = setup(train_b_clean, target = "pv_measurement", train_size = 0.975, categorical_features = ["dew_or_rime__idx", "elevation__m", "is_day__idx", "is_in_shadow__idx", "precip_type_5min__idx", "snow_drift__idx", "wind_speed_w_1000hPa__ms"], session_id = 0)
# best_b = compare_models(fold = 20, sort = "MAE", exclude = ["lar"])
# Out:
# <style type="text/css">
# #T_b335b_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b335b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b335b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b335b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b335b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b335b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b335b_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b335b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b335b_row1_col1" class="data row1 col1" >pv_measurement</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b335b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b335b_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b335b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_b335b_row3_col1" class="data row3 col1" >(32819, 43)</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b335b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_b335b_row4_col1" class="data row4 col1" >(32819, 78)</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b335b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_b335b_row5_col1" class="data row5 col1" >(31998, 78)</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b335b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_b335b_row6_col1" class="data row6 col1" >(821, 78)</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b335b_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_b335b_row7_col1" class="data row7 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b335b_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_b335b_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b335b_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_b335b_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b335b_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_b335b_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b335b_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_b335b_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b335b_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_b335b_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b335b_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_b335b_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b335b_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_b335b_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b335b_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_b335b_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b335b_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_b335b_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b335b_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_b335b_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b335b_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_b335b_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b335b_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_b335b_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_b335b_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_b335b_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b335b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_b335b_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_b335b_row21_col1" class="data row21 col1" >6801</td>
#     </tr>
#   </tbody>
# </table>

# %%
et_b = create_model("et")
# tuned_et_b = tune_model(et_b)
final_et_b = finalize_model(et_b)
pred_et_b_holdout = predict_model(final_et_b)
predictions_et_b = predict_model(final_et_b, data = X_test_b_clean).iloc[:,-1:]
predictions_et_b[predictions_et_b < 0 ] = 0

# %%
lightgbm_b = create_model("lightgbm")
tuned_lightgbm_b = tune_model(lightgbm_b)
final_lightgbm_b = finalize_model(tuned_lightgbm_b)
pred_lightgbm_b_holdout = predict_model(final_lightgbm_b)
predictions_lightgbm_b = predict_model(final_lightgbm_b, data = X_test_b_clean).iloc[:,-1:]
predictions_lightgbm_b[predictions_lightgbm_b < 0 ] = 0

# %%
cat_b = setup_b.create_model("catboost")
tuned_cat_b = tune_model(cat_b)
final_cat_b = finalize_model(tuned_cat_b)
pred_cat_b_holdout = predict_model(final_cat_b)
predictions_cat_b = predict_model(final_cat_b, data = X_test_b_clean).iloc[:,-1:]
predictions_cat_b[predictions_cat_b < 0 ] = 0
# Out:
# <style type="text/css">
# #T_d9377_row10_col0, #T_d9377_row10_col1, #T_d9377_row10_col2, #T_d9377_row10_col3, #T_d9377_row10_col4, #T_d9377_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_
td>
#     </tr>
#     <tr>
#       <th id="T_d9377_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d9377_row7_col0" class="data row7 col0" >1.7385</td>
#       <td id="T_d9377_row7_col1" class="data row7 col1" >8.2208</td>
#       <td id="T_d9377_row7_col2" class="data row7 col2" >2.8672</td>
#       <td id="T_d9377_row7_col3" class="data row7 col3" >0.8784</td>
#       <td id="T_d9377_row7_col4" class="data row7 col4" >0.5729</td>
#       <td id="T_d9377_row7_col5" class="data row7 col5" >0.3504</td>
#     </tr>
#     <tr>
#       <th id="T_d9377_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d9377_row8_col0" class="data row8 col0" >1.7947</td>
#       <td id="T_d9377_row8_col1" class="data row8 col1" >8.5282</td>
#       <td id="T_d9377_row8_col2" class="data row8 col2" >2.9203</td>
#       <td id="T_d9377_row8_col3" class="data row8 col3" >0.8674</td>
#       <td id="T_d9377_row8_col4" class="data row8 col4" >0.5968</td>
#       <td id="T_d9377_row8_col5" class="data row8 col5" >0.3639</td>
#     </tr>
#     <tr>
#       <th id="T_d9377_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d9377_row9_col0" class="data row9 col0" >1.7547</td>
#       <td id="T_d9377_row9_col1" class="data row9 col1" >8.1222</td>
#       <td id="T_d9377_row9_col2" class="data row9 col2" >2.8500</td>
#       <td id="T_d9377_row9_col3" class="data row9 col3" >0.8760</td>
#       <td id="T_d9377_row9_col4" class="data row9 col4" >0.5869</td>
#       <td id="T_d9377_row9_col5" class="data row9 col5" >0.3580</td>
#     </tr>
#     <tr>
#       <th id="T_d9377_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_d9377_row10_col0" class="data row10 col0" >1.7634</td>
#       <td id="T_d9377_row10_col1" class="data row10 col1" >8.3861</td>
#       <td id="T_d9377_row10_col2" class="data row10 col2" >2.8956</td>
#       <td id="T_d9377_row10_col3" class="data row10 col3" >0.8709</td>
#       <td id="T_d9377_row10_col4" class="data row10 col4" >0.5815</td>
#       <td id="T_d9377_row10_col5" class="data row10 col5" >0.3604</td>
#     </tr>
#     <tr>
#       <th id="T_d9377_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_d9377_row11_col0" class="data row11 col0" >0.0221</td>
#       <td id="T_d9377_row11_col1" class="data row11 col1" >0.2288</td>
#       <td id="T_d9377_row11_col2" class="data row11 col2" >0.0396</td>
#       <td id="T_d9377_row11_col3" class="data row11 col3" >0.0063</td>
#       <td id="T_d9377_row11_col4" class="data row11 col4" >0.0103</td>
#       <td id="T_d9377_row11_col5" class="data row11 col5" >0.0231</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d2800_row10_col0, #T_d2800_row10_col1, #T_d2800_row10_col2, #T_d2800_row10_col3, #T_d2800_row10_col4, #T_d2800_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d2800">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2800_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d2800_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d2800_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d2800_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d2800_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d2800_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2800_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2800_row0_col0" class="data row0 col0" >1.8468</td>
#       <td id="T_d2800_row0_col1" class="data row0 col1" >9.0463</td>
#       <td id="T_d2800_row0_col2" class="data row0 col2" >3.0077</td>
#       <td id="T_d2800_row0_col3" class="data row0 col3" >0.8572</td>
#       <td id="T_d2800_row0_col4" class="data row0 col4" >0.5852</td>
#       <td id="T_d2800_row0_col5" class="data row0 col5" >0.3661</td>
#     </tr>
#     <tr>
#       <th id="T_d2800_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d2800_row1_col0" class="data row1 col0" >1.8027</td>
#       <td id="T_d2800_row1_col1" class="data row1 col1" >8.7432</td>
#       <td id="T_d2800_row1_col2" class="data row1 col2" >2.9569</td>
#       <td id="T_d2800_row1_col3" class="data row1 col3" >0.8677</td>
#       <td id="T_d2800_row1_col4" class="data row1 col4" >0.5806</td>
#       <td id="T_d2800_row1_col5" class="data row1 col5" >0.3584</td>
#     </tr>
#     <tr>
#       <th id="T_d2800_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d2800_row2_col0" class="data row2 col0" >1.7777</td>
#       <td id="T_d2800_row2_col1" class="data row2 col1" >8.7321</td>
#       <td id="T_d2800_row2_col2" class="data row2 col2" >2.9550</td>
#       <td id="T_d2800_row2_col3" class="data row2 col3" >0.8628</td>
#       <td id="T_d2800_row2_col4" class="data row2 col4" >0.6036</td>
#       <td id="T_d2800_row2_col5" class="data row2 col5" >0.3453</td>
#     </tr>
#     <tr>
#       <th id="T_d2800_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d2800_row3_col0" class="data row3 col0" >1.8044</td>
#       <td id="T_d2800_row3_col1" class="data row3 col1" >8.7800</td>
#       <td id="T_d2800_row3_col2" class="data row3 col2" >2.9631</td>
#       <td id="T_d2800_row3_col3" class="data row3 col3" >0.8659</td>
#       <td id="T_d2800_row3_col4" class="data row3 col4" >0.5793</td>
#       <td id="T_d2800_row3_col5" class="data row3 col5" >0.3664</td>
#     </tr>
#     <tr>
#       <th id="T_d2800_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d2800_row4_col0" class="data row4 col0" >1.8444</td>
#       <td id="T_d2800_row4_col1" class="data row4 col1" >8.9144</td>
#       <td id="T_d2800_row4_col2" class="data row4 col2" >2.9857</td>
#       <td id="T_d2800_row4_col3" class="data row4 col3" >0.8559</td>
#       <td id="T_d2800_row4_col4" class="data row4 col4" >0.5874</td>
#       <td id="T_d2800_row4_col5" class="data row4 col5" >0.4360</td>
#     </tr>
#     <tr>
#       <th id="T_d2800_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d2800_row5_col0" class="data row5 col0" >1.8027</td>
#       <td id="T_d2800_row5_col1" class="data row5 col1" >8.5675</td>
#       <td id="T_d2800_row5_col2" class="data row5 col2" >2.9270</td>
#       <td id="T_d2800_row5_col3" class="data row5 col3" >0.8697</td>
#       <td id="T_d2800_row5_col4" class="data row5 col4" >0.6004</td>
#       <td id="T_d2800_row5_col5" class="data row5 col5" >0.3655</td>
#     </tr>
#     <tr>
#       <th id="T_d2800_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d2800_row6_col0" class="data row6 col0" >1.8100</td>
#       <td id="T_d2800_row6_col1" class="data row6 col1" >8.4799</td>
#       <td id="T_d2800_row6_col2" class="data row6 col2" >2.9120</td>
#       <td id="T_d2800_row6_col3" class="data row6 col3" >0.8733</td>
#       <td id="T_d2800_row6_col4" class="data row6 col4" >0.5842</td>
#       <td id="T_d2800_row6_col5" class="data row6 col5" >0.3602</td>
#     </tr>
#     <tr>
#       <th id="T_d2800_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d2800_row7_col0" class="data row7 col0" >1.7493</td>
#       <td id="T_d2800_row7_col1" class="data row7 col1" >8.1689</td>
#       <td id="T_d2800_row7_col2" class="data row7 col2" >2.8581</td>
#       <td id="T_d2800_row7_col3" class="data row7 col3" >0.8792</td>
#       <td id="T_d2800_row7_col4" class="data row7 col4" >0.5747</td>
#       <td id="T_d2800_row7_col5" class="data row7 col5" >0.3466</td>
#     </tr>
#     <tr>
#       <th id="T_d2800_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d2800_row8_col0" class="data row8 col0" >1.8280</td>
#       <td id="T_d2800_row8_col1" class="data row8 col1" >8.7179</td>
#       <td id="T_d2800_row8_col2" class="data row8 col2" >2.9526</td>
#       <td id="T_d2800_row8_col3" class="data row8 col3" >0.8644</td>
#       <td id="T_d2800_row8_col4" class="data row8 col4" >0.6041</td>
#       <td id="T_d2800_row8_col5" class="data row8 col5" >0.3707</td>
#     </tr>
#     <tr>
#       <th id="T_d2800_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d2800_row9_col0" class="data row9 col0" >1.7868</td>
#       <td id="T_d2800_row9_col1" class="data row9 col1" >8.4457</td>
#       <td id="T_d2800_row9_col2" class="data row9 col2" >2.9061</td>
#       <td id="T_d2800_row9_col3" class="data row9 col3" >0.8710</td>
#       <td id="T_d2800_row9_col4" class="data row9 col4" >0.5998</td>
#       <td id="T_d2800_row9_col5" class="data row9 col5" >0.3690</td>
#     </tr>
#     <tr>
#       <th id="T_d2800_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_d2800_row10_col0" class="data row10 col0" >1.8053</td>
#       <td id="T_d2800_row10_col1" class="data row10 col1" >8.6596</td>
#       <td id="T_d2800_row10_col2" class="data row10 col2" >2.9424</td>
#       <td id="T_d2800_row10_col3" class="data row10 col3" >0.8667</td>
#       <td id="T_d2800_row10_col4" class="data row10 col4" >0.5899</td>
#       <td id="T_d2800_row10_col5" class="data row10 col5" >0.3684</td>
#     </tr>
#     <tr>
#       <th id="T_d2800_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_d2800_row11_col0" class="data row11 col0" >0.0284</td>
#       <td id="T_d2800_row11_col1" class="data row11 col1" >0.2392</td>
#       <td id="T_d2800_row11_col2" class="data row11 col2" >0.0408</td>
#       <td id="T_d2800_row11_col3" class="data row11 col3" >0.0068</td>
#       <td id="T_d2800_row11_col4" class="data row11 col4" >0.0104</td>
#       <td id="T_d2800_row11_col5" class="data row11 col5" >0.0240</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# </style>
# <table id="T_75ad1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75ad1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_75ad1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_75ad1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_75ad1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_75ad1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_75ad1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_75ad1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75ad1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75ad1_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_75ad1_row0_col1" class="data row0 col1" >1.5192</td>
#       <td id="T_75ad1_row0_col2" class="data row0 col2" >5.6317</td>
#       <td id="T_75ad1_row0_col3" class="data row0 col3" >2.3731</td>
#       <td id="T_75ad1_row0_col4" class="data row0 col4" >0.9098</td>
#       <td id="T_75ad1_row0_col5" class="data row0 col5" >0.5462</td>
#       <td id="T_75ad1_row0_col6" class="data row0 col6" >0.2961</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## C:

# %%
setup_c = setup(train_c_clean, target = "pv_measurement", train_size = 0.97, categorical_features = ["dew_or_rime__idx", "elevation__m", "is_day__idx", "is_in_shadow__idx", "precip_type_5min__idx", "snow_drift__idx", "wind_speed_w_1000hPa__ms"], session_id = 0)
# best_c = compare_models(fold = 20, sort = "MAE", exclude = ["lar"])
# Out:
# <style type="text/css">
# #T_00090_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_00090">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00090_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_00090_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00090_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00090_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_00090_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00090_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_00090_row1_col1" class="data row1 col1" >pv_measurement</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_00090_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_00090_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_00090_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_00090_row3_col1" class="data row3 col1" >(26071, 43)</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_00090_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_00090_row4_col1" class="data row4 col1" >(26071, 80)</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_00090_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_00090_row5_col1" class="data row5 col1" >(25288, 80)</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_00090_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_00090_row6_col1" class="data row6 col1" >(783, 80)</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_00090_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_00090_row7_col1" class="data row7 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_00090_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_00090_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_00090_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_00090_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_00090_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_00090_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_00090_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_00090_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_00090_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_00090_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_00090_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_00090_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_00090_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_00090_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_00090_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_00090_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_00090_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_00090_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_00090_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_00090_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_00090_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_00090_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_00090_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_00090_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_00090_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_00090_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_00090_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_00090_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_00090_row21_col1" class="data row21 col1" >99dd</td>
#     </tr>
#   </tbody>
# </table>

# %%
et_c = create_model("et")
tuned_et_c = tune_model(et_c)
final_et_c = finalize_model(et_c)
# pred_et_c_holdout = predict_model(final_et_c)
predictions_et_c = predict_model(final_et_c, data = X_test_c_clean).iloc[:,-1:]
predictions_et_c[predictions_et_c < 0 ] = 0

# %%
lightgbm_c = create_model("lightgbm")
tuned_lightgbm_c = tune_model(lightgbm_c)
final_lightgbm_c = finalize_model(tuned_lightgbm_c)
pred_lightgbm_c_holdout = predict_model(final_lightgbm_c)
predictions_lightgbm_c = predict_model(final_lightgbm_c, data = X_test_c_clean).iloc[:,-1:]
predictions_lightgbm_c[predictions_lightgbm_c < 0 ] = 0

# %%
cat_c = setup_c.create_model("catboost")
tuned_cat_c = tune_model(cat_c)
final_cat_c = finalize_model(tuned_cat_c)
pred_cat_c_holdout = predict_model(final_cat_c)
predictions_cat_c = predict_model(final_cat_c, data = X_test_c_clean).iloc[:,-1:]
predictions_cat_c[predictions_cat_c < 0 ] = 0
# Out:
# <style type="text/css">
# #T_7aa7b_row10_col0, #T_7aa7b_row10_col1, #T_7aa7b_row10_col2, #T_7aa7b_row10_col3, #T_7aa7b_row10_col4, #T_7aa7b_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7aa7b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7aa7b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7aa7b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7aa7b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7aa7b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7aa7b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7aa7b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7aa7b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7aa7b_row0_col0" class="data row0 col0" >0.8983</td>
#       <td id="T_7aa7b_row0_col1" class="data row0 col1" >2.9215</td>
#       <td id="T_7aa7b_row0_col2" class="data row0 col2" >1.7092</td>
#       <td id="T_7aa7b_row0_col3" class="data row0 col3" >0.9482</td>
#       <td id="T_7aa7b_row0_col4" class="data row0 col4" >0.3429</td>
#       <td id="T_7aa7b_row0_col5" class="data row0 col5" >0.2171</td>
#     </tr>
#     <tr>
#       <th id="T_7aa7b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7aa7b_row1_col0" class="data row1 col0" >0.8624</td>
#       <td id="T_7aa7b_row1_col1" class="data row1 col1" >2.7166</td>
#       <td id="T_7aa7b_row1_col2" class="data row1 col2" >1.6482</td>
#       <td id="T_7aa7b_row1_col3" class="data row1 col3" >0.9473</td>
#       <td id="T_7aa7b_row1_col4" class="data row1 col4" >0.3293</td>
#       <td id="T_7aa7b_row1_col5" class="data row1 col5" >0.2237</td>
#     </tr>
#     <tr>
#       <th id="T_7aa7b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7aa7b_row2_col0" class="data row2 col0" >0.9732</td>
#       <td id="T_7aa7b_row2_col1" class="data row2 col1" >3.4272</td>
#       <td id="T_7aa7b_row2_col2" class="data row2 col2" >1.8513</td>
#       <td id="T_7aa7b_row2_col3" class="data row2 col3" >0.9404</td>
#       <td id="T_7aa7b_row2_col4" class="data row2 col4" >0.3635</td>
#       <td id="T_7aa7b_row2_col5" class="data row2 col5" >0.2243</td>
#     </tr>
#     <tr>
#       <th id="T_7aa7b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7aa7b_row3_col0" class="data row3 col0" >0.9598</td>
#       <td id="T_7aa7b_row3_col1" class="data row3 col1" >3.5379</td>
#       <td id="T_7aa7b_row3_col2" class="data row3 col2" >1.8809</td>
#       <td id="T_7aa7b_row3_col3" class="data row3 col3" >0.9372</td>
#       <td id="T_7aa7b_row3_col4" class="data row3 col4" >0.3822</td>
#       <td id="T_7aa7b_row3_col5" class="data row3 col5" >0.2264</td>
#     </tr>
#     <tr>
#       <th id="T_7aa7b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7aa7b_row4_col0" class="data row4 col0" >0.9142</td>
#       <td id="T_7aa7b_row4_col1" class="data row4 col1" >2.9619</td>
#       <td id="T_7aa7b_row4_col2" class="data row4 col2" >1.7210</td>
#       <td id="T_7aa7b_row4_col3" class="data row4 col3" >0.9470</td>
#       <td id="T_7aa7b_row4_col4" class="data row4 col4" >0.3308</td>
#       <td id="T_7aa7b_row4_col5" class="data row4 col5" >0.2315</td>
#     </tr>
#     <tr>
#       <th id="T_7aa7b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7aa7b_row5_col0" class="data row5 col0" >0.9025</td>
#       <td id="T_7aa7b_row5_col1" class="data row5 col1" >3.3344</td>
#       <td id="T_7aa7b_row5_col2" class="data row5 col2" >1.8260</td>
#       <td id="T_7aa7b_row5_col3" class="data row5 col3" >0.9369</td>
#       <td id="T_7aa7b_row5_col4" class="data row5 col4" >0.3653</td>
#       <td id="T_7aa7b_row5_col5" class="data row5 col5" >0.2190</td>
#     </tr>
#     <tr>
#       <th id="T_7aa7b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7aa7b_row6_col0" class="data row6 col0" >0.8946</td>
#       <td id="T_7aa7b_row6_col1" class="data row6 col1" >2.9578</td>
#       <td id="T_7aa7b_row6_col2" class="data row6 col2" >1.7198</td>
#       <td id="T_7aa7b_row6_col3" class="data row6 col3" >0.9479</td>
#       <td id="T_7aa7b_row6_col4" class="data row6 col4" >0.3497</td>
#       <td id="T_7aa7b_row6_col5" class="data row6 col5" >0.2019</td>
#     </tr>
#     <tr>
#       <th id="T_7aa7b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7aa7b_row7_col0" class="data row7 col0" >0.9239</td>
#       <td id="T_7aa7b_row7_col1" class="data row7 col1" >3.1362</td>
#       <td id="T_7aa7b_row7_col2" class="data row7 col2" >1.7709</td>
#       <td id="T_7aa7b_row7_col3" class="data row7 col3" >0.9457</td>
#       <td id="T_7aa7b_row7_col4" class="data row7 col4" >0.3502</td>
#       <td id="T_7aa7b_row7_col5" class="data row7 col5" >0.2197</td>
#     </tr>
#     <tr>
#       <th id="T_7aa7b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7aa7b_row8_col0" class="data row8 col0" >0.9647</td>
#       <td id="T_7aa7b_row8_col1" class="data row8 col1" >3.3660</td>
#       <td id="T_7aa7b_row8_col2" class="data row8 col2" >1.8347</td>
#       <td id="T_7aa7b_row8_col3" class="data row8 col3" >0.9371</td>
#       <td id="T_7aa7b_row8_col4" class="data row8 col4" >0.3601</td>
#       <td id="T_7aa7b_row8_col5" class="data row8 col5" >0.2330</td>
#     </tr>
#     <tr>
#       <th id="T_7aa7b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7aa7b_row9_col0" class="data row9 col0" >0.9031</td>
#       <td id="T_7aa7b_row9_col1" class="data row9 col1" >2.8563</td>
#       <td id="T_7aa7b_row9_col2" class="data row9 col2" >1.6901</td>
#       <td id="T_7aa7b_row9_col3" class="data row9 col3" >0.9481</td>
#       <td id="T_7aa7b_row9_col4" class="data row9 col4" >0.3490</td>
#       <td id="T_7aa7b_row9_col5" class="data row9 col5" >0.2231</td>
#     </tr>
#     <tr>
#       <th id="T_7aa7b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_7aa7b_row10_col0" class="data row10 col0" >0.9197</td>
#       <td id="T_7aa7b_row10_col1" class="data row10 col1" >3.1216</td>
#       <td id="T_7aa7b_row10_col2" class="data row10 col2" >1.7652</td>
#       <td id="T_7aa7b_row10_col3" class="data row10 col3" >0.9436</td>
#       <td id="T_7aa7b_row10_col4" class="data row10 col4" >0.3523</td>
#       <td id="T_7aa7b_row10_col5" class="data row10 col5" >0.2220</td>
#     </tr>
#     <tr>
#       <th id="T_7aa7b_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_7aa7b_row11_col0" class="data row11 col0" >0.0339</td>
#       <td id="T_7aa7b_row11_col1" class="data row11 col1" >0.2643</td>
#       <td id="T_7aa7b_row11_col2" class="data row11 col2" >0.0747</td>
#       <td id="T_7aa7b_row11_col3" class="data row11 col3" >0.0048</td>
#       <td id="T_7aa7b_row11_col4" class="data row11 col4" >0.0153</td>
#       <td id="T_7aa7b_row11_col5" class="data row11 col5" >0.0083</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T
td>
#     </tr>
#     <tr>
#       <th id="T_564cc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_564cc_row7_col0" class="data row7 col0" >0.9563</td>
#       <td id="T_564cc_row7_col1" class="data row7 col1" >3.3123</td>
#       <td id="T_564cc_row7_col2" class="data row7 col2" >1.8200</td>
#       <td id="T_564cc_row7_col3" class="data row7 col3" >0.9427</td>
#       <td id="T_564cc_row7_col4" class="data row7 col4" >0.3550</td>
#       <td id="T_564cc_row7_col5" class="data row7 col5" >0.2265</td>
#     </tr>
#     <tr>
#       <th id="T_564cc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_564cc_row8_col0" class="data row8 col0" >0.9786</td>
#       <td id="T_564cc_row8_col1" class="data row8 col1" >3.4573</td>
#       <td id="T_564cc_row8_col2" class="data row8 col2" >1.8594</td>
#       <td id="T_564cc_row8_col3" class="data row8 col3" >0.9354</td>
#       <td id="T_564cc_row8_col4" class="data row8 col4" >0.3648</td>
#       <td id="T_564cc_row8_col5" class="data row8 col5" >0.2375</td>
#     </tr>
#     <tr>
#       <th id="T_564cc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_564cc_row9_col0" class="data row9 col0" >0.9217</td>
#       <td id="T_564cc_row9_col1" class="data row9 col1" >3.0332</td>
#       <td id="T_564cc_row9_col2" class="data row9 col2" >1.7416</td>
#       <td id="T_564cc_row9_col3" class="data row9 col3" >0.9449</td>
#       <td id="T_564cc_row9_col4" class="data row9 col4" >0.3542</td>
#       <td id="T_564cc_row9_col5" class="data row9 col5" >0.2267</td>
#     </tr>
#     <tr>
#       <th id="T_564cc_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_564cc_row10_col0" class="data row10 col0" >0.9471</td>
#       <td id="T_564cc_row10_col1" class="data row10 col1" >3.2775</td>
#       <td id="T_564cc_row10_col2" class="data row10 col2" >1.8090</td>
#       <td id="T_564cc_row10_col3" class="data row10 col3" >0.9408</td>
#       <td id="T_564cc_row10_col4" class="data row10 col4" >0.3561</td>
#       <td id="T_564cc_row10_col5" class="data row10 col5" >0.2283</td>
#     </tr>
#     <tr>
#       <th id="T_564cc_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_564cc_row11_col0" class="data row11 col0" >0.0371</td>
#       <td id="T_564cc_row11_col1" class="data row11 col1" >0.2596</td>
#       <td id="T_564cc_row11_col2" class="data row11 col2" >0.0717</td>
#       <td id="T_564cc_row11_col3" class="data row11 col3" >0.0044</td>
#       <td id="T_564cc_row11_col4" class="data row11 col4" >0.0156</td>
#       <td id="T_564cc_row11_col5" class="data row11 col5" >0.0092</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# <style type="text/css">
# </style>
# <table id="T_0868d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0868d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0868d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0868d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0868d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0868d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0868d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0868d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0868d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0868d_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_0868d_row0_col1" class="data row0 col1" >0.7307</td>
#       <td id="T_0868d_row0_col2" class="data row0 col2" >1.6311</td>
#       <td id="T_0868d_row0_col3" class="data row0 col3" >1.2771</td>
#       <td id="T_0868d_row0_col4" class="data row0 col4" >0.9734</td>
#       <td id="T_0868d_row0_col5" class="data row0 col5" >0.3075</td>
#       <td id="T_0868d_row0_col6" class="data row0 col6" >0.1640</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Export

# %%
mf.export_csv(np.concatenate([predictions_cat_a, predictions_cat_b, predictions_cat_c])**2, "PyCaret_Tuned_Sqrt_CatBoost")
# mf.export_csv(np.concatenate([predictions_lightgbm_a, predictions_lightgbm_b, predictions_lightgbm_c]), "PyCaret_Tuned_LightGBM")
# mf.export_csv(np.concatenate([predictions_et_a, predictions_et_b, predictions_et_c]), "PyCaret_Extra_Trees")
